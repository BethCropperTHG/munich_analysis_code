# %%
import numpy as np

xs40 = np.array([1.91592018268878, 1.84201887133254, 1.82035048934717, 1.83346218782765, 1.95647017849238])
e40 = np.array([0.030926643970232,0.084975745957218,0.119201201014009,0.067709786160767,0.16658544255482])

xs31 = np.array([3.00053935218303,2.97239972837506,3.01602973725407,3.00800510866697,2.91435661662106])
e31 = np.array([0.035077901309667,0.473761546268121,0.485830922447924,0.094139236991213,0.162770005829802])

xs25 = np.array([4.65283825691474,4.07932572192992,4.25652870562466,4.46276880967201,4.60859708951141])
e25 = np.array([0.123512501348638,0.373750552311289,0.268625319205835,0.243948633166865,0.719344654885103])

xs18 = np.array([3.0793775299859,2.64448716317195,2.72087666126213,2.77992177024867,3.38067489542824])
e18 = np.array([0.118118529912863,0.220776984787618,0.125487346102022,0.107214190435241,0.408177918589954])

# %%
avg40 = np.average(xs40, weights = 1/e40**2)
err40 = np.sqrt(1/np.sum(1/e40**2))

avg31 = np.average(xs31, weights = 1/e31**2)
err31 = np.sqrt(1/np.sum(1/e31**2))

avg25 = np.average(xs25, weights = 1/e25**2)
err25 = np.sqrt(1/np.sum(1/e25**2))

avg18 = np.average(xs18, weights = 1/e18**2)
err18 = np.sqrt(1/np.sum(1/e18**2))

# %%
angles_list = [40,31,25,18]
ratios_list = [avg40, avg31, avg25, avg18]
error_list = [err40, err31, err25, err18]

# %%
error_list
# Out:
# [0.025746645049429338,
#  0.032075345945859965,
#  0.097449085828732,
#  0.06341171578110583]

# %%
ratios_list
# Out:
# [1.8937233144384864, 2.9979979193910493, 4.5305530693163245, 2.854475576971908]

# %%
import glob
import pandas as pd
files_to_norm = glob.glob('/home/ben/Documents/analysis_code/spectrum_analysis/output/*')

for file in files_to_norm:
    for i,angle in enumerate(angles_list):
        if float(file[75:77]) == float(angle):
            dfg = pd.read_table(file, sep = ' ')
            newfilename = file + '_old'
            dfg.to_csv(newfilename, sep = ' ')
            dfg['CROSS_SECTION'] = dfg['CROSS_SECTION'] * ratios_list[i]
            dfg['ERROR'] = dfg['CROSS_SECTION'] * ((dfg['ERROR']/(dfg['CROSS_SECTION']/ratios_list[i]))**2 + (error_list[i]/ratios_list[i])**2)**0.5
            dfg.to_csv(file, sep = ' ')
            
dfg
# Out:
#     Unnamed: 0  PEAK_POSITION  PEAK_ENERGY  CROSS_SECTION     ERROR
# 0            0        1727.10  1222.000000       0.103778  0.005897
# 1            1        1690.00  1237.000000       0.016223  0.003109
# 2            2        1670.60  1257.000000       0.093042  0.005631
# 3            3        1639.10  1279.000000       0.164136  0.007269
# 4            4        1583.80  1313.909737       0.028390  0.003362
# 5            5        1541.80  1343.000000       0.029821  0.003839
# 6            6        1523.60  1355.000000       0.137416  0.006936
# 7            7           0.00  1406.000000       0.000000       NaN
# 8            8           0.00  1422.000000       0.000000       NaN
# 9            9           0.00  1441.000000       0.000000       NaN
# 10          10        1348.80  1476.000000       0.182267  0.011716
# 11          11        1336.00  1485.137377       0.118808  0.010385
# 12          12           0.00  1650.000000       0.000000       NaN
# 13          13           0.00  1673.000000       0.000000       NaN
# 14          14           0.00  1683.000000       0.000000       NaN
# 15          15           0.00  1695.000000       0.000000       NaN
# 16          16           0.00  1743.000000       0.000000       NaN
# 17          17           0.00  1763.000000       0.000000       NaN
# 18          18           0.00  1792.000000       0.000000       NaN
# 19          19           0.00  1813.000000       0.000000       NaN
# 20          20         854.90  1844.488405       0.172008  0.007984
# 21          21         808.70  1880.866650       0.210895  0.008603
# 22          22         729.80  1943.000000       0.652487  0.016236
# 23          23         654.00  2005.064061       0.123579  0.007120
# 24          24         631.50  2023.433692       0.204931  0.008803
# 25          25         602.00  2047.636058       0.065368  0.005559
# 26          26         576.40  2068.747053       0.203022  0.009021
# 27          27         502.17  2131.000000       0.460677  0.019860
# 28          28         491.80  2139.227852       0.247635  0.017972
# 29          29           0.00  1259.000000       0.000000       NaN
# 30          30           0.00  2183.000000       0.000000       NaN
# 31          31           0.00  2203.000000       0.000000       NaN
# 32          32           0.00  2210.000000       0.000000       NaN
# 33          33           0.00  2232.000000       0.000000       NaN
# 34          34           0.00  2272.000000       0.000000       NaN
# 35          35           0.00  2301.000000       0.000000       NaN
# 36          36           0.00  2317.000000       0.000000       NaN
# 37          37           0.00  2349.000000       0.000000       NaN
# 38          38           0.00  2371.000000       0.000000       NaN
# 39          39           0.00  2395.000000       0.000000       NaN
# 40          40           0.00  2417.000000       0.000000       NaN
# 41          41         178.00  2410.252082       0.043420  0.007895
# 42          42         159.00  2427.147412       0.004056  0.004772
# 43          43         136.00  2447.673796       0.194195  0.015260
# 44          44         121.40  2460.745721       0.021233  0.005018
# 45          45         108.70  2472.143117       0.044135  0.005757
# 46          46          93.90  2485.456359       0.011690  0.004059
# 47          47          65.00  2511.550097       0.021471  0.014317
# 48          48          58.20  2517.708433       0.118569  0.015353
# 49          49          47.10  2527.776260       0.034354  0.006220
# 50          50          35.30  2538.499735       0.073479  0.007463
# 51          51          24.30  2548.515444       0.070617  0.006985

# %%
ls
# Out:
# 116Cd_d,p_117Cd_10degrees_bite_2_peaks.txt  energy_xsection_writer.py
# 116Cd_d,p_bite_1/                           feb_may_normalisation/
# 116Cd_d,p_bite_1_new/                       input/
# 116Cd_d,p_bite_1_patrickbic/                newfilename
# 116Cd_d,p_bite_1_unnorm/                    notebook.aux
# 116Cd_d,t_bite_1/                           notebook.log
# 116Cd_p,d_115Cd_39degrees_bite_1_peaks.txt  notebook.out
# 116Cd_p,d_bite_1/                           notebook.pdf
# 116Cd_p,d_bite_1_different_bic/             notebook.synctex.gz
# 116Cd_p,d_bite_2/                           notebook.tex
# 116Cd_p,d_bite_3/                           output/
# angle_dependent_normalisation.ipynb         output_13_0.png
# angle_norms_2.ipynb                         output_18_0.png
# bic_correction.ods                          __pycache__/
# bite_normalisation_checker.ipynb            run_properties/
# Cross-section-checker.ipynb                 spectroscopic_checker.ipynb
# Distribution Troubleshooting.ipynb          spectrum_classes.py
