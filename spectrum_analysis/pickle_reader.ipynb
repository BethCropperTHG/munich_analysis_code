# %%
import pandas as pd

# %%
fname = "./116Cd_d,p_bite_1_2ndpass/input/116Cd_d,p_117Cd_18degrees_bite_1_peaks.pkl"

# %%
df = pd.read_pickle(fname)

# %%
df
# Out:
#     POSITION  sPOSITION  WIDTH  sWIDTH  HEIGHT  sHEIGHT   AREA  sAREA  \
# 0    1861.10       0.15   9.41    0.09   125.0      3.0   1857     43
# 1    1704.10       0.50   9.34    0.09    11.0      0.9    162     13
# 2    1664.14       0.09   9.31    0.09   837.0     11.0  12324    115
# 3    1442.68       0.25   9.20    0.09    41.3      1.7    103     10
# 4    1379.10       6.00   0.00    0.00     0.0      0.0     32      6
# 5    1284.10       0.60  11.55    0.15     8.3      0.9    126     13
# 6    1264.10       0.30  11.54    0.15    31.2      1.7    473     25
# 7    1242.51       0.16  11.53    0.15   149.0      4.0   2260     50
# 8    1170.90       0.30  11.49    0.15    32.2      1.7    487     24
# 9    1139.41       0.18  11.47    0.15   108.0      3.0   1626     42
# 10   1007.80       1.40   8.36    0.20     3.2      0.8     41     10
# 11    993.10       1.00   8.36    0.20     5.4      0.9     68     11
# ...
